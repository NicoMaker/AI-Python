# %% [markdown]
# CSV

# %%
# python -m pip install pandas

import pandas as pd

data =  pd.read_csv("D:\\Corso ITS IIOT\\2 anno\AI Python\AI-Python\\4 lezione 13_12_2023\Codice\Macchine Learning\\Dati per es\\csv2.CSV")
print(data)  #stamppa dati

data.info()
for row in data:
    print(row)
data.to_csv("D:\\Corso ITS IIOT\\2 anno\AI Python\AI-Python\\4 lezione 13_12_2023\Codice\Macchine Learning\\IRIS\\Result IRIS\\outputfilecsv.csv" , index=None, header=True)
# Out:
#             Codice;Nome;Data
# 0        001;Lino;17/11/2000
# 1      002;Andrea;18/10/1980
# 2     003;Giorgia;19/11/1989
# 3      004;Monica;17/11/2000
# 4       005;Paolo;18/10/1980
# 5    006;Giovanni;19/11/1989
# 6      007;Andrea;17/11/2000
# 7      008;enrico;18/10/1980
# 8      009;silvia;19/11/1989
# 9       010;elena;17/11/2000
# 10   011;federica;18/10/1980
# 11      012;carlo;19/11/1989
# 12   013;cristian;17/11/2000
# 13  014;raffaella;18/10/1980
# 14      015;maria;19/11/1989
# 15    016;sabrina;17/11/2000
# 16     017;simona;18/10/1980
# 17    018;barbara;19/11/1989
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Codice;Nome;Data  18 non-null     object
# dtypes: object(1)
# memory usage: 276.0+ bytes
# Codice;Nome;Data

# %% [markdown]
# Excel

# %%
# python -m pip install pandas
# python -m pip install openpyxl

import pandas as pd
import openpyxl

data =  pd.read_csv("D:\\Corso ITS IIOT\\2 anno\\AI Python\\AI-Python\\4 lezione 13_12_2023\\Codice\\Macchine Learning\\Dati per es\\csv2.CSV")
print(data)  #stamppa dati

data.info()
for row in data:
    print(row)
data.to_excel("D:\\Corso ITS IIOT\\2 anno\\AI Python\\AI-Python\\4 lezione 13_12_2023\\Codice\\Macchine Learning\\IRIS\\Result IRIS\\outputfileexcel.xlsx" , index=False)
# Out:
#             Codice;Nome;Data
# 0        001;Lino;17/11/2000
# 1      002;Andrea;18/10/1980
# 2     003;Giorgia;19/11/1989
# 3      004;Monica;17/11/2000
# 4       005;Paolo;18/10/1980
# 5    006;Giovanni;19/11/1989
# 6      007;Andrea;17/11/2000
# 7      008;enrico;18/10/1980
# 8      009;silvia;19/11/1989
# 9       010;elena;17/11/2000
# 10   011;federica;18/10/1980
# 11      012;carlo;19/11/1989
# 12   013;cristian;17/11/2000
# 13  014;raffaella;18/10/1980
# 14      015;maria;19/11/1989
# 15    016;sabrina;17/11/2000
# 16     017;simona;18/10/1980
# 17    018;barbara;19/11/1989
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Codice;Nome;Data  18 non-null     object
# dtypes: object(1)
# memory usage: 276.0+ bytes
# Codice;Nome;Data

# %% [markdown]
# Word

# %%
# python -m pip install docx2txt

import docx2txt
mytext = docx2txt.process("D:\\Corso ITS IIOT\\2 anno\AI Python\AI-Python\\4 lezione 13_12_2023\Codice\Macchine Learning\\Dati per es\\doc1.docx")
print(mytext)
# Out:
# Ciao. Sono Lino

# %% [markdown]
# TXT

# %%
import pandas as pd
import openpyxl

data = pd.read_csv('C:\dati\csv2.csv', sep=';')
print(data) #visualizza i dati
data.info() #visualizza struttura dataframe e nomi di colonne
for row in data: #visualizza nomi di colonne
    print(row)
data.to_csv (r'C:\dati\lezione-iiot.csv', index = None, header=True) #salva in file dataframe.csv il dataframe con nome data
#data.to_excel(r'C:\dati\exportexcel.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 import openpyxl
# ----> 4 data = pd.read_csv('C:\dati\csv2.csv', sep=';')
#       5 print(data) #visualizza i dati
#       6 data.info() #visualizza struttura dataframe e nomi di colonne
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\dati\\csv2.csv'

# %% [markdown]
# Fiori nome fiori

# %%
# python -m pip install scikit-learn

from sklearn.datasets import load_iris
iris = load_iris()

x = iris.data
y = iris.target

print(x.shape, y.shape)
print(iris.feature_names, iris.target_names)
# Out:
# (150, 4) (150,)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'] ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# Fiori 3d

# %%
# python -m pip install matplotlib

from sklearn import datasets

iris = datasets.load_iris()
import matplotlib.pyplot as plt

_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
ax.set(xlabel=iris.feature_names[0], ylabel=iris.feature_names[1])
_ = ax.legend(
    scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes"
)
import mpl_toolkits.mplot3d  # noqa: F401

from sklearn.decomposition import PCA

fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d", elev=-150, azim=110)

X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    X_reduced[:, 2],
    c=iris.target,
    s=40,
)

ax.set_title("First three PCA dimensions")
ax.set_xlabel("1st Eigenvector")
ax.xaxis.set_ticklabels([])
ax.set_ylabel("2nd Eigenvector")
ax.yaxis.set_ticklabels([])
ax.set_zlabel("3rd Eigenvector")
ax.zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# Fiori Predizione

# %%
#importazione librerie necessarie

import numpy as np
from sklearn import datasets #riferimento ai dati di esempio
from sklearn.model_selection import train_test_split #organizza dati learning
from sklearn.linear_model import Perceptron #modello di predizione scelto
from sklearn.metrics import accuracy_score #calcolo dell'accuratezza

#carica gli specifici dati Iris
iris = datasets.load_iris()
X = iris.data #input
y = iris.target #output

#divide in insiemi di training 80% e test 20% e senza scelta casuale  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

#impostazione parametri del modello neural network Perceptron
ppn = Perceptron(max_iter=40, tol=0.001, eta0=0.01, random_state=0,verbose=10)
#supervised learning del modello scelto
ppn.fit(X_train, y_train)

#predizione sul test set
y_pred = ppn.predict(X_test)

#verifica errore sul test set
print('accuratezza della predizione',accuracy_score(y_test, y_pred))

#messa in esercizio su nuovi dati di un oggetto da classificare
print ("classe predetta",ppn.predict([[1.3, 1.2, 4.1, 2.4]]))
print ("classe predetta",ppn.predict([[4,11, 3, 3]]))
# Out:
# -- Epoch 1
# Norm: 0.16, NNZs: 4, Bias: 0.020000, T: 120, Avg. loss: 0.012639
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 240, Avg. loss: 0.000816
# Total training time: 0.01 seconds.
# -- Epoch 3
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 360, Avg. loss: 0.000000
# Total training time: 0.01 seconds.
# -- Epoch 4
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 480, Avg. loss: 0.000000
# Total training time: 0.01 seconds.
# -- Epoch 5
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 600, Avg. loss: 0.000000
# Total training time: 0.01 seconds.
# -- Epoch 6
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 720, Avg. loss: 0.000000
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 0.17, NNZs: 4, Bias: 0.020000, T: 840, Avg. loss: 0.000000
# Total training time: 0.01 seconds.
# Convergence after 7 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.12, NNZs: 4, Bias: 0.020000, T: 120, Avg. loss: 0.141273
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.13, NNZs: 4, Bias: 0.030000, T: 240, Avg. loss: 0.117391
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.19, NNZs: 4, Bias: 0.030000, T: 360, Avg. loss: 0.108115
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.23, NNZs: 4, Bias: 0.040000, T: 480, Avg. loss: 0.132732
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.20, NNZs: 4, Bias: 0.070000, T: 600, Avg. loss: 0.135681
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.23, NNZs: 4, Bias: 0.090000, T: 720, Avg. loss: 0.147966
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.27, NNZs: 4, Bias: 0.110000, T: 840, Avg. loss: 0.111018
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.30, NNZs: 4, Bias: 0.120000, T: 960, Avg. loss: 0.127262
# Total training time: 0.00 seconds.
# Convergence after 8 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.25, NNZs: 4, Bias: -0.050000, T: 120, Avg. loss: 0.092067
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.33, NNZs: 4, Bias: -0.060000, T: 240, Avg. loss: 0.032078
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.38, NNZs: 4, Bias: -0.080000, T: 360, Avg. loss: 0.059943
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.47, NNZs: 4, Bias: -0.100000, T: 480, Avg. loss: 0.055533
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.51, NNZs: 4, Bias: -0.100000, T: 600, Avg. loss: 0.030113
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.55, NNZs: 4, Bias: -0.120000, T: 720, Avg. loss: 0.027548
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.58, NNZs: 4, Bias: -0.130000, T: 840, Avg. loss: 0.026523
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.62, NNZs: 4, Bias: -0.130000, T: 960, Avg. loss: 0.027444
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.61, NNZs: 4, Bias: -0.150000, T: 1080, Avg. loss: 0.017466
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.65, NNZs: 4, Bias: -0.150000, T: 1200, Avg. loss: 0.025904
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.69, NNZs: 4, Bias: -0.160000, T: 1320, Avg. loss: 0.021139
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.71, NNZs: 4, Bias: -0.170000, T: 1440, Avg. loss: 0.013336
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.75, NNZs: 4, Bias: -0.180000, T: 1560, Avg. loss: 0.026133
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.80, NNZs: 4, Bias: -0.200000, T: 1680, Avg. loss: 0.027267
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.84, NNZs: 4, Bias: -0.210000, T: 1800, Avg. loss: 0.024219
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 0.86, NNZs: 4, Bias: -0.220000, T: 1920, Avg. loss: 0.031142
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 0.87, NNZs: 4, Bias: -0.220000, T: 2040, Avg. loss: 0.013497
# Total training time: 0.00 seconds.
# Convergence after 17 epochs took 0.00 seconds
# accuratezza della predizione 1.0
# classe predetta [2]
# classe predetta [0]
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s

# %% [markdown]
# PDF

# %%
# python -m pip install PyPDF2 

from PyPDF2 import PdfReader
file = PdfReader("D:\\Corso ITS IIOT\\2 anno\AI Python\AI-Python\\4 lezione 13_12_2023\Codice\Macchine Learning\\Dati per es\\doc1.pdf")
number_of_pages = len(file.pages)
print(number_of_pages)
page = file.pages[0]
text = page.extract_text()
print(text)
# Out:
# 1
# Ciao. Sono Lino
